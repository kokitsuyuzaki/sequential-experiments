# %% [markdown]
# # 系列データにおける馬蹄効果の確認

# %% [markdown]
# ## パッケージのインストール

# %%
if(!require("fields", quietly = TRUE))
    install.packages("fields")
if(!require("tagcloud", quietly = TRUE))
    install.packages("tagcloud")
if(!require("FactoMineR", quietly = TRUE))
    install.packages("FactoMineR")
# Out:
# Spam version 2.11-0 (2024-10-03) is loaded.
# Type 'help( Spam)' or 'demo( spam)' for a short introduction
# and overview of this package.
# Help for individual functions is also obtained by adding the
# suffix '.spam' to the function name, e.g. 'help( chol.spam)'.
#
#
# 次のパッケージを付け加えます: ‘spam’
#
#
# 以下のオブジェクトは ‘package:base’ からマスクされています:
#
#     backsolve, forwardsolve
#
#
#
# Try help(fields) to get started.

# %% [markdown]
# ## パッケージのロード

# %%
library("fields")
library("tagcloud")
library("FactoMineR")

# %% [markdown]
# ## 関数定義

# %%
seq_color <- function(n){
	smoothPalette(-seq_len(n), pal="RdBu")
}

image.plot2 <- function(x){
	x <- t(x)
	image.plot(x[, ncol(x):1], xaxt="n", yaxt="n")
}

# %% [markdown]
# ## 人工データの作成

# %%
data_zero <- matrix(0, nrow=30, ncol=25)

data_diagonal <- data_zero
diag(data_diagonal) <- 1

data_band_narrow <- data_zero
diag(data_band_narrow) <- 1
diag(data_band_narrow[2:nrow(data_band_narrow), ]) <- 1
diag(data_band_narrow[, 2:ncol(data_band_narrow)]) <- 1

data_band_medium <- data_band_narrow
diag(data_band_medium[3:nrow(data_band_medium), ]) <- 1
diag(data_band_medium[, 3:ncol(data_band_medium)]) <- 1

data_band_wide <- data_band_medium
diag(data_band_wide[4:nrow(data_band_wide), ]) <- 1
diag(data_band_wide[5:nrow(data_band_wide), ]) <- 1
diag(data_band_wide[, 4:ncol(data_band_wide)]) <- 1
diag(data_band_wide[, 5:ncol(data_band_wide)]) <- 1

data_band_gauss <- data_zero
diag(data_band_gauss) <- 5
diag(data_band_gauss[2:nrow(data_band_gauss), ]) <- 3
diag(data_band_gauss[, 2:ncol(data_band_gauss)]) <- 3
diag(data_band_gauss[3:nrow(data_band_gauss), ]) <- 1
diag(data_band_gauss[, 3:ncol(data_band_gauss)]) <- 1

data_richness <- data_zero
diag(data_richness) <- 1
data_richness[lower.tri(data_richness)] <- 1

data_linear <- matrix(0, nrow=30, ncol=25)
data_linear[1:5, ] <- rep(1E-3*(1:ncol(data_linear)), each=5)

set.seed(1234)
data_seq <- runif(10)
data_shift <- data_zero
for(i in seq(16)){
	data_shift[i, i:(i+10-1)] <- data_seq
}

set.seed(1234)
data_seq <- 1E+10*runif(54)
k <- 30
data_hankel <- sapply(seq_along(data_seq), function(x){data_seq[x:(x+k-1)]})
data_hankel <- data_hankel[, 1:25]

# %% [markdown]
# ## 人工データの可視化

# %%
layout(rbind(1:3, 4:6, 7:9))
options(repr.plot.width = 10, repr.plot.height = 10)
image.plot2(data_diagonal)
image.plot2(data_band_narrow)
image.plot2(data_band_medium)
image.plot2(data_band_wide)
image.plot2(data_band_gauss)
image.plot2(data_richness)
image.plot2(data_linear)
image.plot2(data_shift)
image.plot2(data_hankel)
# Out:
# plot without title

# %% [markdown]
# ## 内積行列の可視化

# %%
layout(rbind(1:3, 4:6, 7:9))
options(repr.plot.width = 10, repr.plot.height = 10)
image.plot2(t(data_diagonal) %*% data_diagonal)
image.plot2(t(data_band_narrow) %*% data_band_narrow)
image.plot2(t(data_band_medium) %*% data_band_medium)
image.plot2(t(data_band_wide) %*% data_band_wide)
image.plot2(t(data_band_gauss) %*% data_band_gauss)
image.plot2(t(data_richness) %*% data_richness)
image.plot2(t(data_linear) %*% data_linear)
image.plot2(t(data_shift) %*% data_shift)
image.plot2(t(data_hankel) %*% data_hankel)
# Out:
# plot without title

# %% [markdown]
# ## 共分散行列の可視化（Toepritz行列ライクになっていることを確認）

# %%
data_diagonal_norm <- t(scale(t(data_diagonal), center=TRUE, scale=FALSE))
data_band_narrow_norm <- t(scale(t(data_band_narrow), center=TRUE, scale=FALSE))
data_band_medium_norm <- t(scale(t(data_band_medium), center=TRUE, scale=FALSE))
data_band_wide_norm <- t(scale(t(data_band_wide), center=TRUE, scale=FALSE))
data_band_gauss_norm <- t(scale(t(data_band_gauss), center=TRUE, scale=FALSE))
data_richness_norm <- t(scale(t(data_richness), center=TRUE, scale=FALSE))
data_linear_norm <- t(scale(t(data_linear), center=TRUE, scale=FALSE))
data_shift_norm <- t(scale(t(data_shift), center=TRUE, scale=FALSE))
data_hankel_norm <- t(scale(t(data_hankel), center=TRUE, scale=FALSE))

layout(rbind(1:3, 4:6, 7:9))
options(repr.plot.width = 10, repr.plot.height = 10)
image.plot2(t(data_diagonal_norm) %*% data_diagonal_norm)
image.plot2(t(data_band_narrow_norm) %*% data_band_narrow_norm)
image.plot2(t(data_band_medium_norm) %*% data_band_medium_norm)
image.plot2(t(data_band_wide_norm) %*% data_band_wide_norm)
image.plot2(t(data_band_gauss_norm) %*% data_band_gauss_norm)
image.plot2(t(data_richness_norm) %*% data_richness_norm)
image.plot2(t(data_linear_norm) %*% data_linear_norm)
image.plot2(t(data_shift_norm) %*% data_shift_norm)
image.plot2(t(data_hankel_norm) %*% data_hankel_norm)
# Out:
# plot without title

# %% [markdown]
# ## PCAのスコアが馬蹄鉄形であることを確認

# %%
## PCA
pca_score_diagonal <- prcomp(t(data_diagonal), center=TRUE, scale=FALSE)$x
pca_score_band_narrow <- prcomp(t(data_band_narrow), center=TRUE, scale=FALSE)$x
pca_score_band_medium <- prcomp(t(data_band_medium), center=TRUE, scale=FALSE)$x
pca_score_band_wide <- prcomp(t(data_band_wide), center=TRUE, scale=FALSE)$x
pca_score_band_gauss <- prcomp(t(data_band_gauss), center=TRUE, scale=FALSE)$x
pca_score_richness <- prcomp(t(data_richness), center=TRUE, scale=FALSE)$x
pca_score_linear <- prcomp(t(data_linear), center=TRUE, scale=FALSE)$x
pca_score_shift <- prcomp(t(data_shift), center=TRUE, scale=FALSE)$x
pca_score_hankel <- prcomp(t(data_hankel), center=TRUE, scale=FALSE)$x

## Score Plot (PCA)
layout(rbind(1:3, 4:6, 7:9))
options(repr.plot.width = 8, repr.plot.height = 8)
plot(pca_score_diagonal[,1:2], type="o", pch=19, col=seq_color(nrow(pca_score_diagonal)))
plot(pca_score_band_narrow[,1:2], type="o", pch=19, col=seq_color(nrow(pca_score_band_narrow)))
plot(pca_score_band_medium[,1:2], type="o", pch=19, col=seq_color(nrow(pca_score_band_medium)))
plot(pca_score_band_wide[,1:2], type="o", pch=19, col=seq_color(nrow(pca_score_band_wide)))
plot(pca_score_band_gauss[,1:2], type="o", pch=19, col=seq_color(nrow(pca_score_band_gauss)))
plot(pca_score_richness[,1:2], type="o", pch=19, col=seq_color(nrow(pca_score_richness)))
plot(pca_score_linear[,1:2], type="o", pch=19, col=seq_color(nrow(pca_score_linear)))
plot(pca_score_shift[,1:2], type="o", pch=19, col=seq_color(nrow(pca_score_shift)))
plot(pca_score_hankel[,1:2], type="o", pch=19, col=seq_color(nrow(pca_score_hankel)))
# Out:
# plot without title

# %% [markdown]
# ## PCAの高次スコアが振動していることを確認

# %%
# 対角行列では振動しない
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(pca_score_diagonal[,i], type="o", pch=19)
}
# Out:
# plot without title

# %%
# 帯行列だと振動する
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(pca_score_band_narrow[,i], type="o", pch=19)
}
# Out:
# plot without title

# %%
# 帯行列だと振動する
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(pca_score_band_medium[,i], type="o", pch=19)
}
# Out:
# plot without title

# %%
# 帯行列だと振動する
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(pca_score_band_wide[,i], type="o", pch=19)
}
# Out:
# plot without title

# %%
# ガウス帯行列だと振動する
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(pca_score_band_gauss[,i], type="o", pch=19)
}
# Out:
# plot without title

# %%
# リッチネス行列だと振動する
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(pca_score_richness[,i], type="o", pch=19)
}
# Out:
# plot without title

# %%
# リニア行列ではリニアな基底が出るだけ
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(pca_score_linear[,i], type="o", pch=19)
}
# Out:
# plot without title

# %%
# シフト行列だと振動する
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(pca_score_shift[,i], type="o", pch=19)
}
# Out:
# plot without title

# %%
# ハンケル行列だと振動する
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(pca_score_hankel[,i], type="o", pch=19)
}
# Out:
# plot without title

# %% [markdown]
# ## CAのスコアがアーチ状であることを確認

# %%
## CA
ca_score_diagonal = CA(t(data_diagonal), graph=FALSE)$col$coord
ca_score_band_narrow = CA(t(data_band_narrow), graph=FALSE)$col$coord
ca_score_band_medium = CA(t(data_band_medium), graph=FALSE)$col$coord
ca_score_band_wide = CA(t(data_band_wide), graph=FALSE)$col$coord
ca_score_band_gauss = CA(t(data_band_gauss), graph=FALSE)$col$coord
ca_score_richness = CA(t(data_richness), graph=FALSE)$col$coord
ca_score_linear = CA(t(data_linear), graph=FALSE)$col$coord
ca_score_shift = CA(t(data_shift), graph=FALSE)$col$coord
ca_score_hankel = CA(t(data_hankel), graph=FALSE)$col$coord

## Score Plot (CA)
layout(rbind(1:3, 4:6, 7:9))
options(repr.plot.width = 8, repr.plot.height = 8)
plot(ca_score_diagonal[,1:2], type="o", pch=19, col=seq_color(nrow(ca_score_diagonal)))
plot(ca_score_band_narrow[,1:2], type="o", pch=19, col=seq_color(nrow(ca_score_band_narrow)))
plot(ca_score_band_medium[,1:2], type="o", pch=19, col=seq_color(nrow(ca_score_band_medium)))
plot(ca_score_band_wide[,1:2], type="o", pch=19, col=seq_color(nrow(ca_score_band_wide)))
plot(ca_score_band_gauss[,1:2], type="o", pch=19, col=seq_color(nrow(ca_score_band_gauss)))
plot(ca_score_richness[,1:2], type="o", pch=19, col=seq_color(nrow(ca_score_richness)))
plot(ca_score_linear[,1:2], type="o", pch=19, col=seq_color(nrow(ca_score_linear)))
plot(ca_score_shift[,1:2], type="o", pch=19, col=seq_color(nrow(ca_score_shift)))
plot(ca_score_hankel[,1:2], type="o", pch=19, col=seq_color(nrow(ca_score_hankel)))
# Out:
# Warning message in CA(t(data_diagonal), graph = FALSE):
# “The columns V26, V27, V28, V29, V30 sum at 0. They were suppressed from the analysis”
# Warning message in CA(t(data_band_narrow), graph = FALSE):
# “The columns V27, V28, V29, V30 sum at 0. They were suppressed from the analysis”
# Warning message in CA(t(data_band_medium), graph = FALSE):
# “The columns V28, V29, V30 sum at 0. They were suppressed from the analysis”
# Warning message in CA(t(data_band_wide), graph = FALSE):
# “The columns V30 sum at 0. They were suppressed from the analysis”
# Warning message in CA(t(data_band_gauss), graph = FALSE):
# “The columns V28, V29, V30 sum at 0. They were suppressed from the analysis”
# Warning message in CA(t(data_linear), graph = FALSE):
# “The columns V6, V7, V8, V9, V10, V11, V12, V13, V14, V15, V16, V17, V18, V19, V20, V21, V22, V23, V24, V25, V26, V27, V28, V29, V30 sum at 0. They were suppressed from the analysis”
# Warning message in CA(t(data_shift), graph = FALSE):
# “The columns V17, V18, V19, V20, V21, V22, V23, V24, V25, V26, V27, V28, V29, V30 sum at 0. They were suppressed from the analysis”
# plot without title

# %% [markdown]
# ## CAの高次スコアが振動していることを確認

# %%
# 対角行列だと振動しない
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(ca_score_diagonal[,i], type="o", pch=19)
}
# Out:
# plot without title

# %%
# 帯行列だと振動する
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(ca_score_band_narrow[,i], type="o", pch=19)
}
# Out:
# plot without title

# %%
# 帯行列だと振動する
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(ca_score_band_medium[,i], type="o", pch=19)
}
# Out:
# plot without title

# %%
# 帯行列だと振動する
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(ca_score_band_wide[,i], type="o", pch=19)
}
# Out:
# plot without title

# %%
# ガウス帯行列だと振動する
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(ca_score_band_gauss[,i], type="o", pch=19)
}
# Out:
# plot without title

# %%
# リッチネス行列だと?
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(ca_score_richness[,i], type="o", pch=19)
}
# Out:
# plot without title

# %%
# リニア行列だと？
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(ca_score_linear[,i], type="o", pch=19)
}
# Out:
# Error in ca_score_linear[, i]: 添え字が許される範囲外です
# Traceback:
# plot without title

# %%
# シフト行列だと振動する
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(ca_score_shift[,i], type="o", pch=19)
}

# %%
# ハンケル行列だと振動する
layout(as.matrix(1:5))
options(repr.plot.width = 5, repr.plot.height = 10)
for(i in 1:5){
	plot(ca_score_hankel[,i], type="o", pch=19)
}

# %% [markdown]
# ## Session Information

# %%
sessionInfo()
